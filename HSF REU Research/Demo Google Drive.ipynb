# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from os import listdir
from os.path import isfile, join

onlyfiles = [f for f in listdir('/content/drive/My Drive/') if isfile(join('/content/drive/My Drive/', f))]

print(onlyfiles)
# Out:
# ['whaaaaaaaaa.png', 'Copy of Hour Tracker.gsheet', 'IEE380.pdf', 'Resume 2018 v3.docx', 'Resume 2018 v3 - Michael Li.docx', 'IMG_20190201_224403.jpg', 'IMG_20190201_224327 (2).jpg', 'IMG_20190201_224327 (1).jpg', 'IMG_20190201_224327.jpg', 'IMG_20190201_224321.jpg', 'IMG_20190201_224312.jpg', 'qYgnRMb.jpg', 'Li M 1 (1).jpg', 'Li M 3 (1).jpg', 'Li M 2 (1).jpg', 'Li M 4 (1).jpg', 'Li M 4.jpg', 'Li M 2.jpg', 'Li M 1.jpg', 'Li M 5 All.jpg', 'Li M 3.jpg', 'moms yelling at me again.jpg', 'Empower - ASU IT Professional Community Day.pdf', 'poster.ai', 'dragonboat first practice 2019.zip', 'Resume 2019 v7.docx', 'asd.zip', 'Debate Topics.gdoc', 'Sprint Retrospective 4 - Line chart 1.gsheet', 'resume v10.pdf', 'cover_letter_statefarm.pdf', 'JPN110 202008.gdoc', 'cover_letter_deloitte.pdf', 'cover_letter_chase.pdf', 'resume v11.pdf', '344779.344855.pdf', 'resume v11.1.pdf', 'cover_letter_light.pdf', 'cover_letter_thethirdfloor.pdf', 'cover_letter_riot.pdf', 'Resources for Honors Thesis.gdoc', 
# ...
