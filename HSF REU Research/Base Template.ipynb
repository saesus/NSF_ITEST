# %% [markdown]
# # **Python Setup**

# %% [markdown]
# **Dependencies**

# %%
# Import Packages

# Image Plotting Packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Math Packages
import numpy as np
import cv2

# File System Packages
import os
from google.colab import files

# %% [markdown]
# **Function Setup**

# %%
# Displays an image, converts BGR to RGB
def display_one(a, title = "Original"):
    a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
    plt.imshow(a), plt.title(title)
    plt.show()

# Displays an RGB image
def display_one_rgb(a, title = "Original"):
    plt.imshow(a), plt.title(title)
    plt.show()

# %% [markdown]
# # **Loading and Saving Images in Google Colab**
